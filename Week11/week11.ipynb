# %% [markdown]
# # Week 11

# %% [markdown]
# 1️⃣ K-Means Clustering

# %%
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Load dataset
iris = load_iris()
X = iris.data[:, :2]  # Using two features for visualization

# Apply K-Means
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)

labels = kmeans.labels_

# Plot clusters
plt.scatter(X[:,0], X[:,1], c=labels)
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.title("K-Means Clustering")

plt.show()
# Out:
# c:\Users\prash\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# 2️⃣ Hierarchical Clustering

# %% [markdown]
# a. Agglomerative Hierarchical Clustering

# %%
from sklearn.datasets import load_iris
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt

# Load dataset
iris = load_iris()
X = iris.data[:, :2]

# Hierarchical clustering
Z = linkage(X, method='ward')

# Plot dendrogram
plt.figure(figsize=(8,5))
dendrogram(Z)

plt.title("Hierarchical Clustering Dendrogram")
plt.xlabel("Samples")
plt.ylabel("Distance")

plt.show()

# %% [markdown]
# b. Divisive Hierarchical clustering

# %%
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Load data
X = load_iris().data[:, :2]

# Step 1: Split into 2 clusters (Top-down)
kmeans1 = KMeans(n_clusters=2, random_state=0).fit(X)
labels1 = kmeans1.labels_

# Step 2: Split one cluster again
cluster0 = X[labels1 == 0]

kmeans2 = KMeans(n_clusters=2, random_state=0).fit(cluster0)
labels2 = kmeans2.labels_

# Plot
plt.scatter(X[:, 0], X[:, 1], c=labels1)  # first split
plt.scatter(cluster0[:, 0], cluster0[:, 1], c=labels2, marker='x')  # second split

plt.title("Simple Divisive Clustering")
plt.show()
# Out:
# c:\Users\prash\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# 3️⃣ DBSCAN Clustering

# %%
from sklearn.datasets import load_iris
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt

# Load dataset
iris = load_iris()
X = iris.data[:, :2]

# Apply DBSCAN
db = DBSCAN(eps=0.5, min_samples=5)
labels = db.fit_predict(X)

# Plot clusters
plt.scatter(X[:,0], X[:,1], c=labels)

plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.title("DBSCAN Clustering")

plt.show()
