# %% [markdown]
# # Week 5

# %% [markdown]
# Apriori Algorithm

# %%
import warnings
warnings.filterwarnings('ignore')  # ignore all warnings

# %%
# !pip install mlxtend pandas
# Out:
# Requirement already satisfied: mlxtend in c:\users\prash\anaconda3\lib\site-packages (0.24.0)
# Requirement already satisfied: pandas in c:\users\prash\anaconda3\lib\site-packages (3.0.2)
# Requirement already satisfied: scipy>=1.16.3 in c:\users\prash\anaconda3\lib\site-packages (from mlxtend) (1.17.1)
# Requirement already satisfied: numpy>=2.3.5 in c:\users\prash\anaconda3\lib\site-packages (from mlxtend) (2.4.4)
# Requirement already satisfied: scikit-learn>=1.8.0 in c:\users\prash\anaconda3\lib\site-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: matplotlib>=3.10.8 in c:\users\prash\anaconda3\lib\site-packages (from mlxtend) (3.10.8)
# Requirement already satisfied: joblib>=1.5.2 in c:\users\prash\anaconda3\lib\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\prash\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\prash\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\prash\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\prash\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\prash\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\prash\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\prash\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\prash\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (11.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\prash\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (3.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\prash\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\prash\anaconda3\lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.5.0)

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# Creating market basket dataset
data = {
    'Milk':   [1,0,1,1,0,1],
    'Bread':  [1,1,1,0,1,1],
    'Butter': [1,1,0,0,0,1],
    'Eggs':   [0,0,1,1,1,1]
}

# Convert into dataframe
df = pd.DataFrame(data)

print("Market Basket Dataset:")
print(df)

# Generate Frequent Itemsets using Apriori
frequent_items = apriori(df, min_support=0.3, use_colnames=True)

print("\nFrequent Itemsets:")
print(frequent_items)

# Generate Association Rules
rules = association_rules(frequent_items, metric="confidence", min_threshold=0.6)

print("\nAssociation Rules:")
print(rules)
# Out:
# Market Basket Dataset:
#    Milk  Bread  Butter  Eggs
# 0     1      1       1     0
# 1     0      1       1     0
# 2     1      1       0     1
# 3     1      0       0     1
# 4     0      1       0     1
# 5     1      1       1     1
#
# Frequent Itemsets:
#      support                          itemsets
# 0   0.666667                 frozenset({Milk})
# 1   0.833333                frozenset({Bread})
# 2   0.500000               frozenset({Butter})
# 3   0.666667                 frozenset({Eggs})
# 4   0.500000          frozenset({Bread, Milk})
# 5   0.333333         frozenset({Milk, Butter})
# 6   0.500000           frozenset({Milk, Eggs})
# 7   0.500000        frozenset({Bread, Butter})
# 8   0.500000          frozenset({Bread, Eggs})
# 9   0.333333  frozenset({Bread, Milk, Butter})
# 10  0.333333    frozenset({Bread, Milk, Eggs})
#
# Association Rules:
#                    antecedents               consequents  antecedent support  \
# 0           frozenset({Bread})         frozenset({Milk})            0.833333
# 1            frozenset({Milk})        frozenset({Bread})            0.666667
# 2          frozenset({Butter})         frozenset({Milk})            0.500000
# 3            frozenset({Milk})         frozenset({Eggs})            0.666667
# 4            frozenset({Eggs})         frozenset({Milk})            0.666667
# 5           frozenset({Bread})       frozenset({Butter})            0.833333
# 6          frozenset({Butter})        frozenset({Bread})            0.500000
# 7           frozenset({Bread})         frozenset({Eggs})            0.833333
# 8            frozenset({Eggs})        frozenset({Bread})            0.666667
# 9     frozenset({Bread, Milk})       frozenset({Butter})            0.500000
# 10  frozenset({Bread, Butter})         frozenset({Milk})            0.500000
# 11   frozenset({Milk, Butter})        frozenset({Bread})            0.333333
# 12         frozenset({Butter})  frozenset({Bread, Milk})            0.500000
# 13    frozenset({Bread, Milk})         frozenset({Eggs})            0.500000
# 14    frozenset({Bread, Eggs})         frozenset({Milk})            0.500000
# 15     frozenset({Milk, Eggs})        frozenset({Bread})            0.500000
#
#     consequent support   support  confidence      lift  representativity  \
# 0             0.666667  0.500000    0.600000  0.900000               1.0
# 1             0.833333  0.500000    0.750000  0.900000               1.0
# 2             0.666667  0.333333    0.666667  1.000000               1.0
# 3             0.666667  0.500000    0.750000  1.125000               1.0
# 4             0.666667  0.500000    0.750000  1.125000               1.0
# 5             0.500000  0.500000    0.600000  1.200000               1.0
# 6             0.833333  0.500000    1.000000  1.200000               1.0
# 7             0.666667  0.500000    0.600000  0.900000               1.0
# 8             0.833333  0.500000    0.750000  0.900000               1.0
# 9             0.500000  0.333333    0.666667  1.333333               1.0
# 10            0.666667  0.333333    0.666667  1.000000               1.0
# 11            0.833333  0.333333    1.000000  1.200000               1.0
# 12            0.500000  0.333333    0.666667  1.333333               1.0
# 13            0.666667  0.333333    0.666667  1.000000               1.0
# 14            0.666667  0.333333    0.666667  1.000000               1.0
# 15            0.833333  0.333333    0.666667  0.800000               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0  -0.055556    0.833333      -0.400000  0.500000  -0.200000    0.675000
# 1  -0.055556    0.666667      -0.250000  0.500000  -0.500000    0.675000
# 2   0.000000    1.000000       0.000000  0.400000   0.000000    0.583333
# 3   0.055556    1.333333       0.333333  0.600000   0.250000    0.750000
# 4   0.055556    1.333333       0.333333  0.600000   0.250000    0.750000
# 5   0.083333    1.250000       1.000000  0.600000   0.200000    0.800000
# 6   0.083333         inf       0.333333  0.600000   1.000000    0.800000
# 7  -0.055556    0.833333      -0.400000  0.500000  -0.200000    0.675000
# 8  -0.055556    0.666667      -0.250000  0.500000  -0.500000    0.675000
# 9   0.083333    1.500000       0.500000  0.500000   0.333333    0.666667
# 10  0.000000    1.000000       0.000000  0.400000   0.000000    0.583333
# 11  0.055556         inf       0.250000  0.400000   1.000000    0.700000
# 12  0.083333    1.500000       0.500000  0.500000   0.333333    0.666667
# 13  0.000000    1.000000       0.000000  0.400000   0.000000    0.583333
# 14  0.000000    1.000000       0.000000  0.400000   0.000000    0.583333
# 15 -0.083333    0.500000      -0.333333  0.333333  -1.000000    0.533333
