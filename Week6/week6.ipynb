# %% [markdown]
# # Week 6

# %% [markdown]
# FP-Growth

# %%
import warnings
warnings.filterwarnings('ignore')  # ignore all warnings

# %%
import pandas as pd
from mlxtend.frequent_patterns import fpgrowth, association_rules

# Create market basket dataset
data = {
    'Milk':   [1,0,1,1,0,1],
    'Bread':  [1,1,1,0,1,1],
    'Butter': [1,1,0,0,0,1],
    'Eggs':   [0,0,1,1,1,1]
}

# Convert to DataFrame
df = pd.DataFrame(data)

print("Market Basket Dataset:")
print(df)

# Generate Frequent Itemsets using FP-Growth
frequent_items = fpgrowth(df, min_support=0.3, use_colnames=True)

print("\nFrequent Itemsets:")
print(frequent_items)

# Generate Association Rules
rules = association_rules(frequent_items, metric="confidence", min_threshold=0.6)

print("\nAssociation Rules:")
print(rules)
# Out:
# Market Basket Dataset:
#    Milk  Bread  Butter  Eggs
# 0     1      1       1     0
# 1     0      1       1     0
# 2     1      1       0     1
# 3     1      0       0     1
# 4     0      1       0     1
# 5     1      1       1     1
#
# Frequent Itemsets:
#      support                          itemsets
# 0   0.833333                frozenset({Bread})
# 1   0.666667                 frozenset({Milk})
# 2   0.500000               frozenset({Butter})
# 3   0.666667                 frozenset({Eggs})
# 4   0.500000          frozenset({Milk, Bread})
# 5   0.500000           frozenset({Milk, Eggs})
# 6   0.333333    frozenset({Milk, Bread, Eggs})
# 7   0.500000        frozenset({Butter, Bread})
# 8   0.333333         frozenset({Milk, Butter})
# 9   0.333333  frozenset({Milk, Butter, Bread})
# 10  0.500000          frozenset({Bread, Eggs})
#
# Association Rules:
#                    antecedents               consequents  antecedent support  \
# 0            frozenset({Milk})        frozenset({Bread})            0.666667
# 1           frozenset({Bread})         frozenset({Milk})            0.833333
# 2            frozenset({Milk})         frozenset({Eggs})            0.666667
# 3            frozenset({Eggs})         frozenset({Milk})            0.666667
# 4     frozenset({Milk, Bread})         frozenset({Eggs})            0.500000
# 5      frozenset({Milk, Eggs})        frozenset({Bread})            0.500000
# 6     frozenset({Bread, Eggs})         frozenset({Milk})            0.500000
# 7          frozenset({Butter})        frozenset({Bread})            0.500000
# 8           frozenset({Bread})       frozenset({Butter})            0.833333
# 9          frozenset({Butter})         frozenset({Milk})            0.500000
# 10   frozenset({Milk, Butter})        frozenset({Bread})            0.333333
# 11    frozenset({Milk, Bread})       frozenset({Butter})            0.500000
# 12  frozenset({Butter, Bread})         frozenset({Milk})            0.500000
# 13         frozenset({Butter})  frozenset({Milk, Bread})            0.500000
# 14          frozenset({Bread})         frozenset({Eggs})            0.833333
# 15           frozenset({Eggs})        frozenset({Bread})            0.666667
#
#     consequent support   support  confidence      lift  representativity  \
# 0             0.833333  0.500000    0.750000  0.900000               1.0
# 1             0.666667  0.500000    0.600000  0.900000               1.0
# 2             0.666667  0.500000    0.750000  1.125000               1.0
# 3             0.666667  0.500000    0.750000  1.125000               1.0
# 4             0.666667  0.333333    0.666667  1.000000               1.0
# 5             0.833333  0.333333    0.666667  0.800000               1.0
# 6             0.666667  0.333333    0.666667  1.000000               1.0
# 7             0.833333  0.500000    1.000000  1.200000               1.0
# 8             0.500000  0.500000    0.600000  1.200000               1.0
# 9             0.666667  0.333333    0.666667  1.000000               1.0
# 10            0.833333  0.333333    1.000000  1.200000               1.0
# 11            0.500000  0.333333    0.666667  1.333333               1.0
# 12            0.666667  0.333333    0.666667  1.000000               1.0
# 13            0.500000  0.333333    0.666667  1.333333               1.0
# 14            0.666667  0.500000    0.600000  0.900000               1.0
# 15            0.833333  0.500000    0.750000  0.900000               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0  -0.055556    0.666667      -0.250000  0.500000  -0.500000    0.675000
# 1  -0.055556    0.833333      -0.400000  0.500000  -0.200000    0.675000
# 2   0.055556    1.333333       0.333333  0.600000   0.250000    0.750000
# 3   0.055556    1.333333       0.333333  0.600000   0.250000    0.750000
# 4   0.000000    1.000000       0.000000  0.400000   0.000000    0.583333
# 5  -0.083333    0.500000      -0.333333  0.333333  -1.000000    0.533333
# 6   0.000000    1.000000       0.000000  0.400000   0.000000    0.583333
# 7   0.083333         inf       0.333333  0.600000   1.000000    0.800000
# 8   0.083333    1.250000       1.000000  0.600000   0.200000    0.800000
# 9   0.000000    1.000000       0.000000  0.400000   0.000000    0.583333
# 10  0.055556         inf       0.250000  0.400000   1.000000    0.700000
# 11  0.083333    1.500000       0.500000  0.500000   0.333333    0.666667
# 12  0.000000    1.000000       0.000000  0.400000   0.000000    0.583333
# 13  0.083333    1.500000       0.500000  0.500000   0.333333    0.666667
# 14 -0.055556    0.833333      -0.400000  0.500000  -0.200000    0.675000
# 15 -0.055556    0.666667      -0.250000  0.500000  -0.500000    0.675000
# c:\Users\prash\anaconda3\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:175: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
